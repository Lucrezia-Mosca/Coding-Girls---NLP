# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucrezia-Mosca/Coding-Girls---NLP/blob/main/Temperature_Sampling_Top_K_Sampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
from huggingface_hub import login

# Token di accesso al modello
#token = "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"

# Effettua il login con il token
login(token)

# Inizializza la pipeline di generazione testo
generator = pipeline("text-generation", model="meta-llama/Llama-3.2-1B", token=token)

# Prompt di partenza
prompt = "Era una notte buia e tempestosa"

# Temperature diverse
temperatures = [0.2, 0.7, 1.5]
print("\n=== Esercizio 1: Temperature Sampling ===")
for temp in temperatures:
    print(f"\nGenerazione con temperature={temp}:")
    output = generator(prompt, max_new_tokens=100, do_sample=True, temperature=temp)[0]["generated_text"]
    print(output)

# Valori di Top-K diversi
top_k_values = [5, 20, 50]
print("\n=== Esercizio 2: Top-K Sampling ===")
for k in top_k_values:
    print(f"\nGenerazione con top_k={k}:")
    output = generator(prompt, max_new_tokens=100, do_sample=True, top_k=k)[0]["generated_text"]
    print(output)

# Combinazioni di Temperature e Top-K
combinations = [(0.3, 50), (1.2, 10)]
print("\n=== Esercizio 3: Combinazione di Temperature e Top-K ===")
for temp, k in combinations:
    print(f"\nGenerazione con temperature={temp} e top_k={k}:")
    output = generator(prompt, max_new_tokens=100, do_sample=True, temperature=temp, top_k=k)[0]["generated_text"]
    print(output)
# Out:
# config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# Device set to use cpu
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# === Esercizio 1: Temperature Sampling ===
#
# Generazione con temperature=0.2:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Era una notte buia e tempestosa, e la luna era piena di stelle. E la luna era piena di stelle, e la luna era piena di stelle, e la luna era piena di stelle, e la luna era piena di stelle, e la luna era piena di stelle, e la luna era piena di stelle, e la luna era piena di stelle, e la luna era piena di stelle,
#
# Generazione con temperature=0.7:
# ...
